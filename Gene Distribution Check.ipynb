# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import torch
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %%
from src.reference_data import read_sgd

sgd_all = read_sgd('../archive/cadmium-paper/data/saccharomyces_cerevisiae_R64-1-1_20110208_no_fasta.gff')

# %%
from src.reference_data import read_sgd_orfs

sgd = read_sgd_orfs('../archive/cadmium-paper/data/saccharomyces_cerevisiae_R64-1-1_20110208_no_fasta.gff')

# %%
def get_gene_cats(sgd, chrom):
    chrom_genes = sgd[(sgd.chr == chrom)]
    chrom_watson_genes = chrom_genes[chrom_genes.strand == '+']
    
    chrom_watson_ver = chrom_watson_genes[chrom_watson_genes.orf_class == 'Verified']
    chrom_watson_unchar = chrom_watson_genes[chrom_watson_genes.orf_class == 'Uncharacterized']
    chrom_watson_dub = chrom_watson_genes[chrom_watson_genes.orf_class == 'Dubious']
    chrom_watson_rib = chrom_watson_genes[chrom_watson_genes['ontology'].str.contains('GO:0003735')]

    return chrom_genes, chrom_watson_genes, chrom_watson_ver, chrom_watson_unchar, \
            chrom_watson_dub, chrom_watson_rib

# %%
sgd
# Out:
#                 name  chr   start    stop  length strand        orf_class  \
# orf_name
# YAL069W      YAL069W    1     335     649     315      +          Dubious
# YAL068W-A  YAL068W-A    1     538     792     255      +          Dubious
# YAL068C         PAU8    1    1807    2169     363      -         Verified
# YAL067W-A  YAL067W-A    1    2480    2707     228      +  Uncharacterized
# YAL067C         SEO1    1    7235    9016    1782      -         Verified
# ...              ...  ...     ...     ...     ...    ...              ...
# YPR201W         ARR3   16  939922  941136    1215      +         Verified
# YPR202W      YPR202W   16  943032  943896     865      +  Uncharacterized
# YPR203W      YPR203W   16  943880  944188     309      +  Uncharacterized
# YPR204W      YPR204W   16  944603  947701    3099      +  Uncharacterized
# YPR204C-A  YPR204C-A   16  946856  947338     483      -          Dubious
#
#                                                     ontology
# orf_name
# YAL069W                     GO:0003674,GO:0005575,GO:0008150
# YAL068W-A                   GO:0003674,GO:0005575,GO:0008150
# YAL068C          GO:0003674,GO:0005575,GO:0030437,GO:0045944
# YAL067W-A                   GO:0003674,GO:0005575,GO:0008150
# YAL067C                     GO:0005215,GO:0006810,GO:0016020
# ...                                                      ...
# YPR201W    GO:0005886,GO:0015104,GO:0015105,GO:0015699,GO...
# YPR202W                     GO:0003674,GO:0005575,GO:0008150
# YPR203W                     GO:0003674,GO:0005575,GO:0008150
# YPR204W                     GO:0003678,GO:0005575,GO:0008150
# YPR204C-A                   GO:0003674,GO:0005575,GO:0008150
#
# [6575 rows x 8 columns]

# %%
def plot_chrom_dat(chrom):
    
    chrom_rows = sgd_all[sgd_all.cat == 'chromosome']
    chrom_row = chrom_rows[chrom_rows.chr == chrom]
    chrom_row = chrom_rows.loc[chrom_row.index.values[0]]
    start, end = chrom_row.start, chrom_row.stop

    print(start, end)
    (chrom_genes, chrom_watson_genes, 
     chrom_watson_ver, chrom_watson_unchar, 
     chrom_watson_dub, chrom_rib) = get_gene_cats(chrom)
    
    fig = plt.figure(figsize=(12, 6))

    def _plot_series(plt_data, y, col):
        plt_data = plt_data['start'].values
        plt.scatter(plt_data, np.zeros_like(plt_data)+y, s=20, c=col)

    def plot_subplots():
        _plot_series(chrom_watson_genes, 0, '#ddd')
        _plot_series(chrom_watson_dub, 1, 'gray')
        _plot_series(chrom_watson_unchar, 2, 'pink')
        _plot_series(chrom_watson_ver, 3, 'red')
        _plot_series(chrom_rib, 4, 'purple')
        plt.ylim(-1, 5)
    
    plt.subplot(3, 1, 1)
    plot_subplots()

    plt.subplot(3, 1, 2)
    plot_subplots()
    plt.xlim(0, 100000)
    
    plt.subplot(3, 1, 3)
    plot_subplots()
    plt.xlim(end-100000, end)

# %%
""" 
My hypothesis:


Genes at the start of the chromosome are less mature because they have fewer iterations of pol II running through it

Genes at the end are more mature, because the opposite.

I have ideas of maturity and youth of a gene I have previously described. Let's see how it plays out here.

Plot the distribution of dubious, verified, uncharacterized genes...

"""

plot_chrom_dat(1)
# Out:
# 1 230218

# %%
plot_chrom_dat(6)
# Out:
# 1 270161

# %%
plot_chrom_dat(3)
# Out:
# 1 316620

# %%
plot_chrom_dat(9)
# Out:
# 1 439888

# %%
plot_chrom_dat(2)
# Out:
# 1 813184

# %%
"""
My hypothesis doesn't hold true, but I think a different one may be appearing.

There is a density of verified genes 20000-50000. Maybe these genes are 
tightly regulated by fewer polII binding events up here.

We can see if this holds true with chromosome 4, a longer one...
"""

plot_chrom_dat(4)
# Out:
# 1 1531933

# %%
sgd_all[sgd_all.cat == 'chromosome'].sort_values('stop')
# Out:
#        chr         cat  start     stop strand  \
# 16219   -1  chromosome      1    85779      .
# 0        1  chromosome      1   230218      .
# 4727     6  chromosome      1   270161      .
# 1399     3  chromosome      1   316620      .
# 7389     9  chromosome      1   439888      .
# 6590     8  chromosome      1   562643      .
# 3899     5  chromosome      1   576874      .
# 8986    11  chromosome      1   666816      .
# 7997    10  chromosome      1   745751      .
# 12529   14  chromosome      1   784333      .
# 309      2  chromosome      1   813184      .
# 11280   13  chromosome      1   924431      .
# 14967   16  chromosome      1   948066      .
# 9810    12  chromosome      1  1078177      .
# 5126     7  chromosome      1  1090940      .
# 13563   15  chromosome      1  1091291      .
# 1916     4  chromosome      1  1531933      .
#
#                                                 desc
# 16219  ID=chrMito;dbxref=NCBI:NC_001224;Name=chrMito
# 0            ID=chrI;dbxref=NCBI:NC_001133;Name=chrI
# 4727       ID=chrVI;dbxref=NCBI:NC_001138;Name=chrVI
# 1399     ID=chrIII;dbxref=NCBI:NC_001135;Name=chrIII
# 7389       ID=chrIX;dbxref=NCBI:NC_001141;Name=chrIX
# 6590   ID=chrVIII;dbxref=NCBI:NC_001140;Name=chrVIII
# 3899         ID=chrV;dbxref=NCBI:NC_001137;Name=chrV
# 8986       ID=chrXI;dbxref=NCBI:NC_001143;Name=chrXI
# 7997         ID=chrX;dbxref=NCBI:NC_001142;Name=chrX
# 12529    ID=chrXIV;dbxref=NCBI:NC_001146;Name=chrXIV
# 309        ID=chrII;dbxref=NCBI:NC_001134;Name=chrII
# 11280  ID=chrXIII;dbxref=NCBI:NC_001145;Name=chrXIII
# 14967    ID=chrXVI;dbxref=NCBI:NC_001148;Name=chrXVI
# 9810     ID=chrXII;dbxref=NCBI:NC_001144;Name=chrXII
# 5126     ID=chrVII;dbxref=NCBI:NC_001139;Name=chrVII
# 13563      ID=chrXV;dbxref=NCBI:NC_001147;Name=chrXV
# 1916       ID=chrIV;dbxref=NCBI:NC_001136;Name=chrIV

# %%
"""A lot more heterogeneity when looking at more chromosomes, but I think there could be more ways to dilineate
things, by length maybe?


I'll need a way to plot all chromosomes in order of length, first 50000, and last 50000
"""
0
# Out:
# 0

# %%
def plot_gene_locs(sgd):
                
    def _plot_genes(genes, chrom, c):
        starts = genes.start.values
        y = np.zeros_like(starts)+chrom
        plt.scatter(starts, y, s=10, c=c)
                
    def plot_chrom_seg(sgd, end=False):
        
        chrom_lens = sgd_all[sgd_all.cat == 'chromosome'].sort_values('stop').set_index('chr')
               
        for chrom in range(1, 17):
            sgd_copy = sgd.copy()
                
            if end:
                sgd_copy['start'] = sgd_copy.start.values - chrom_lens.loc[chrom].stop

            (chrom_genes, chrom_watson_genes, 
             chrom_watson_ver, chrom_watson_unchar, 
             chrom_watson_dub, chrom_rib) = get_gene_cats(sgd_copy, chrom)
            
            _plot_genes(chrom_watson_dub, chrom, '#ddd')
            _plot_genes(chrom_watson_unchar, chrom, '#57bbed')
            _plot_genes(chrom_watson_ver, chrom, '#046ea3')
            
        if end:
            plt.xlim(-60000, 10000)
            plt.xticks([-50000, 0])
            0
        else:
            plt.xlim(-10000, 60000)
            plt.xticks([0, 50000]) 

        plt.yticks([])
        plt.ylim(-5, 17)

    plt.figure(figsize=(6, 6))
    plt.subplot(1, 2, 1)
    plot_chrom_seg(sgd)

    plt.subplot(1, 2, 2)
    plot_chrom_seg(sgd, end=True)

# %%
plot_gene_locs(sgd)

# %%
plot_gene_locs(sgd[sgd['length'] < 500])

# %%
plot_gene_locs(sgd[sgd['length'] > 2000])

# %%
plt.hist(sgd['length'], bins=50)
plt.xlim(0, 6000)
0
# Out:
# 0

# %%
gene_half_life = pd.read_csv('../archive/cadmium-paper/data/half_life.csv').set_index('orf_name')
gene_half_life.head()

plt.hist(gene_half_life.half_life, bins=60)
plt.xlim(0, 80)
# Out:
# (0.0, 80.0)

# %%
sgd_hl = sgd.join(gene_half_life[['half_life']])
sgd_hl = sgd_hl[~np.isnan(sgd_hl.half_life)]
sgd_hl
# Out:
#                 name  chr   start    stop  length strand        orf_class  \
# orf_name
# YAL067C         SEO1    1    7235    9016    1782      -         Verified
# YAL063C-A  YAL063C-A    1   22395   22685     291      -  Uncharacterized
# YAL063C         FLO9    1   24000   27968    3969      -         Verified
# YAL062W         GDH3    1   31567   32940    1374      +         Verified
# YAL061W         BDH2    1   33448   34701    1254      +  Uncharacterized
# ...              ...  ...     ...     ...     ...    ...              ...
# YPR196W      YPR196W   16  931376  932788    1413      +  Uncharacterized
# YPR198W         SGE1   16  934034  935665    1632      +         Verified
# YPR199C         ARR1   16  938148  939032     885      -         Verified
# YPR201W         ARR3   16  939922  941136    1215      +         Verified
# YPR204W      YPR204W   16  944603  947701    3099      +  Uncharacterized
#
#                                                     ontology  half_life
# orf_name
# YAL067C                     GO:0005215,GO:0006810,GO:0016020  15.000000
# YAL063C-A                   GO:0003674,GO:0005575,GO:0008150  23.000000
# YAL063C          GO:0000128,GO:0000501,GO:0005537,GO:0009277  25.350000
# YAL062W    GO:0004354,GO:0005625,GO:0005634,GO:0005739,GO...  45.000000
# YAL061W          GO:0005634,GO:0005737,GO:0008150,GO:0016616  30.000000
# ...                                                      ...        ...
# YPR196W                     GO:0005575,GO:0008150,GO:0043565  19.000000
# YPR198W          GO:0005887,GO:0015238,GO:0015893,GO:0042493  22.796667
# YPR199C    GO:0003702,GO:0005634,GO:0005737,GO:0043565,GO...  14.653333
# YPR201W    GO:0005886,GO:0015104,GO:0015105,GO:0015699,GO...   6.700000
# YPR204W                     GO:0003678,GO:0005575,GO:0008150   6.860000
#
# [5381 rows x 9 columns]

# %%
plot_gene_locs(sgd_hl[(sgd_hl['length'] > 2000) & (sgd_hl['half_life'] < 20)])
plt.suptitle("Long genes, quick decay")

plot_gene_locs(sgd_hl[(sgd_hl['length'] > 2000) & (sgd_hl['half_life'] > 25)])
plt.suptitle("Long genes, slow decay")
# Out:
# Text(0.5, 0.98, 'Long genes, slow decay')

# %%
plot_gene_locs(sgd_hl[(sgd_hl['length'] < 500) & (sgd_hl['half_life'] < 20)])
plt.suptitle("Short genes, quick decay")

plot_gene_locs(sgd_hl[(sgd_hl['length'] > 500) & (sgd_hl['half_life'] > 25)])
plt.suptitle("Short genes, slow decay")
# Out:
# Text(0.5, 0.98, 'Short genes, slow decay')

# %%
chrom_rows = sgd_all[sgd_all.cat == 'chromosome']
chrom_lens = chrom_rows.set_index('chr')[['stop']].rename(columns={'stop': 'length'})
chrom_lens.head(2)
# Out:
#      length
# chr
# 1    230218
# 2    813184

# %%
# Plot genes in the first 20,000..... decay rate vs length

sgd_hl_adj = sgd_hl.merge(chrom_lens.reset_index(), on=['chr'], suffixes=['', '_chr'])
sgd_hl_adj['start_rel_end'] = sgd_hl_adj['start'] - sgd_hl_adj['length_chr']
sgd_hl_adj
# Out:
#            name  chr   start    stop  length strand        orf_class  \
# 0          SEO1    1    7235    9016    1782      -         Verified
# 1     YAL063C-A    1   22395   22685     291      -  Uncharacterized
# 2          FLO9    1   24000   27968    3969      -         Verified
# 3          GDH3    1   31567   32940    1374      +         Verified
# 4          BDH2    1   33448   34701    1254      +  Uncharacterized
# ...         ...  ...     ...     ...     ...    ...              ...
# 5376    YPR196W   16  931376  932788    1413      +  Uncharacterized
# 5377       SGE1   16  934034  935665    1632      +         Verified
# 5378       ARR1   16  938148  939032     885      -         Verified
# 5379       ARR3   16  939922  941136    1215      +         Verified
# 5380    YPR204W   16  944603  947701    3099      +  Uncharacterized
#
#                                                ontology  half_life  \
# 0                      GO:0005215,GO:0006810,GO:0016020  15.000000
# 1                      GO:0003674,GO:0005575,GO:0008150  23.000000
# 2           GO:0000128,GO:0000501,GO:0005537,GO:0009277  25.350000
# 3     GO:0004354,GO:0005625,GO:0005634,GO:0005739,GO...  45.000000
# 4           GO:0005634,GO:0005737,GO:0008150,GO:0016616  30.000000
# ...                                                 ...        ...
# 5376                   GO:0005575,GO:0008150,GO:0043565  19.000000
# 5377        GO:0005887,GO:0015238,GO:0015893,GO:0042493  22.796667
# 5378  GO:0003702,GO:0005634,GO:0005737,GO:0043565,GO...  14.653333
# 5379  GO:0005886,GO:0015104,GO:0015105,GO:0015699,GO...   6.700000
# 5380                   GO:0003678,GO:0005575,GO:0008150   6.860000
#
#       length_chr  start_rel_end
# 0         230218        -222983
# 1         230218        -207823
# 2         230218        -206218
# 3         230218        -198651
# 4         230218        -196770
# ...          ...            ...
# 5376      948066         -16690
# 5377      948066         -14032
# 5378      948066          -9918
# 5379      948066          -8144
# 5380      948066          -3463
#
# [5381 rows x 11 columns]

# %%
adj_wat = sgd_hl_adj[sgd_hl_adj.strand == '+']

first_20 = adj_wat[(adj_wat.start < 50000)]
plt.scatter(first_20['length'], first_20['half_life'], c=first_20.start, cmap='magma_r')
plt.title("Beginning of the genome")
plt.xlim(0, 2500)
plt.ylim(0, 60)
# plt.colorbar()
plt.show()

last_20 = adj_wat[(adj_wat.start_rel_end > -50000)]
plt.scatter(last_20['length'], last_20['half_life'], c=last_20.start_rel_end, cmap='magma_r')
plt.title("End of the genome")
plt.ylim(0, 60)
plt.xlim(0, 2500)
# plt.colorbar()
# Out:
# (0.0, 2500.0)

# %%
adj_wat = sgd_hl_adj[sgd_hl_adj.strand == '+']

first_20 = adj_wat[(adj_wat.start < 20000)]
plt.scatter(first_20['length'], first_20['half_life'], c=first_20.start, cmap='magma_r', vmax=50000, vmin=0)
plt.title("Beginning of the genome")
plt.xlim(0, 2500)
plt.ylim(0, 60)
# plt.colorbar()
plt.show()

last_20 = adj_wat[(adj_wat.start_rel_end > -20000)]
plt.scatter(last_20['length'], last_20['half_life'], c=last_20.start_rel_end, cmap='magma_r', vmin=-20000, vmax=30000)
plt.title("End of the genome")
plt.ylim(0, 60)
plt.xlim(0, 2500)
# Out:
# (0.0, 2500.0)
