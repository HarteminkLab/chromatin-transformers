# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import torch
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %%
from src.data_loader import ViTDataLoader
from src.vit_train import ViTTrainer, load_model_dir, load_model_config
import importlib
from src.vit_data import load_cell_cycle_data
from src.vit_data import load_cd_data_24x128, load_cell_cycle_data
from src.reference_data import read_orfs_data

config_name = 'cell_cycle_24x_chr4_validchrom_b4'
config = importlib.import_module(f"config.{config_name}")
vit = load_model_config(config)
# vit_data = load_cell_cycle_data()
vit_data = load_cd_data_24x128()

# %%
dataloader = ViTDataLoader(vit_data, split_type='hybrid', split_arg=0.1,
                           valid_type='hybrid', valid_arg=0.1)
# Out:
# Split: hybrid,0.1; Training: 22362; Validation: 1990; Testing: 2210
