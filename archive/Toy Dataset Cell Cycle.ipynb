# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import torch
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cc_dat = pd.read_csv('data/yulong_RNA_fourier_plus_cell_cycling_label_chrom_fourier.csv').set_index('orf_name')

# %%
cc_dat[cc_dat.label == 'non_cell_cycle']
# Out:
#           Gene_name  Fourier_score  P_value       FDR Cell_cycle_phase   idx  \
# orf_name
# YAL031C        GIP4       3.529448  0.43422  0.569451              NaN    23
# YBL106C       SRO77       1.871664  0.79781  0.850125              NaN    60
# YBR084C-A    RPL19A       3.693913  0.40928  0.548560              NaN   197
# YBR110W        ALG1       2.959105  0.55458  0.665187              NaN   217
# YBR191W      RPL21A       3.496681  0.45117  0.584122              NaN   275
# ...             ...            ...      ...       ...              ...   ...
# YPL085W       SEC16       1.326669  0.89056  0.918154              NaN  4220
# YPL031C       PHO85       2.451445  0.69814  0.774787              NaN  4260
# YPL019C        VTC3       3.268332  0.48845  0.615101              NaN  4269
# YPR049C       ATG11       3.853524  0.38370  0.526481              NaN  4322
# YPR180W        AOS1       2.369349  0.69474  0.772701              NaN  4413
#
# ...

# %%
cc_datt
# Out:
#          Gene_name  Fourier_score  P_value       FDR Cell_cycle_phase   idx  \
# orf_name
# YAL063C       FLO9       4.263286  0.28523  0.438953              NaN     0
# YAL062W       GDH3       2.074419  0.77236  0.830606              NaN     1
# YAL061W       BDH2       4.250641  0.28669  0.440745              NaN     2
# YAL060W       BDH1       4.696954  0.21331  0.365096              NaN     3
# YAL059W       ECM1       2.816279  0.58856  0.691914              NaN     4
# ...            ...            ...      ...       ...              ...   ...
# YPR191W       QCR2       8.458399  0.00010  0.001975               G1  4422
# YPR196W    YPR196W       5.845725  0.07645  0.180015              NaN  4423
# YPR198W       SGE1       4.982466  0.17064  0.314019              NaN  4424
# YPR199C       ARR1       5.034164  0.16325  0.304595              NaN  4425
# YPR201W       ARR3       4.219759  0.30827  0.462116              NaN  4426
#
# ...
